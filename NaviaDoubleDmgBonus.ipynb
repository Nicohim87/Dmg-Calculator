# %% [markdown]
# ##  **Rules :**
# - Ditch the percentage sign directly, no need to convert into decimal. example: <br>
#     if the number is 5.5%, **write 5.5** and not 0.055
#
# - Number can be written as python script.

# %% [markdown]
# # **Functions, Helpers, and Hyperparameters**

# %%
from packages.base import *
from packages.disp import *
from packages.stats import stats
from packages.helper import *

# %load_ext autoreload
# %autoreload 2


data = []
for i in range(5):
    data.append(stats())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Hyperparameters

# %%
calculationMode = 0

# Put :
# 0 for Genshin Impat
# 1 for Honkai Star Rail

# %% [markdown]
# # **Global Stats**

# %% [markdown]
# ### Personal Base Stats

# %%
base = complete(

    calculationMode = calculationMode,
    level = 90
    
    ,elementalMastery = 0
    ,energyRecharge = 100
    
# Atk
    ,atkBase = 1026
    ,atkPercent = 0
    ,atkFlat = 1494
    
# Hp
    ,hpBase = 0
    ,hpPercent = 0
    ,hpFlat = 0
    
# Def
    ,defBase = 0
    ,defPercent = 0
    ,defFlat = 0
    
# Dmg
    ,motionValue = 100*Atk
    ,dmgFlat = 0
    
# Dmg Bonus
    ,dmgBonusElemental = 18*2
    ,dmgBonusOther = 0
    
# Crit
    ,critRate = 52.3 + 36
    ,critDmg = 194.1
    
# Multipliers
    ,quickenType = Off
    ,quickenDmgBonus = 0
    ,quickenCount = 1
    ,amplifyType = Off
    ,amplifyDmgBonus = 0
    ,customMultiplier = 1.15
    
# Enemy Stats
    ,levelEnemy = 90
    ,resBase = 10
    ,resShred = 0
    ,defShred = 0
    ,defIgnore = 0
    
# Conversions
    ,convertToAtk = 0
    ,convertToHp = 0
    ,convertToDef = 0
    ,convertToER = 0
    ,convertToEM = 0
    
    ,convertToDmgFlat = 0
    ,convertToDmgBonus = 0
    ,convertToCritRate = 0
    ,convertToCritDmg = 0
    
# Buff Status
    ,buffStatus = True
)

# %% [markdown]
# #### Team Buff / Debuff

# %%
globalBuffs = partial(

        elementalMastery = 0
        ,energyRecharge = 0
    # Atk
        ,atkPercent = 0
        ,atkFlat = 0
    # Hp
        ,hpPercent = 0
        ,hpFlat = 0
    # Def
        ,defPercent = 0
        ,defFlat = 0
    # Dmg
        ,dmgFlat = 0
    # Dmg Bonus
        ,dmgBonusElemental = 0.31*400+40
        ,dmgBonusOther = 0
    # Crit
        ,critRate = 0
        ,critDmg = 0
    # Reaction
        ,quickenDmgBonus = 0
        ,amplifyDmgBonus = 0
    # Enemy Stats
        ,resShred = 20
        ,defShred = 0
        ,defIgnore = 0
)

# %% [markdown]
# # **Unique Stats**

# %% [markdown]
# #### **Data 1**

# %%
label = "Geo Goblet"

custom = complete(

    calculationMode = calculationMode,
    level = Inherit
    
    ,elementalMastery = 0
    ,energyRecharge = 0
    
# Atk
    ,atkBase = Inherit
    ,atkPercent = 5.8
    ,atkFlat = 0
    
# Hp
    ,hpBase = Inherit
    ,hpPercent = 0
    ,hpFlat = 0
    
# Def
    ,defBase = Inherit
    ,defPercent = 0
    ,defFlat = 0
    
# Dmg
    ,motionValue = Inherit
    ,dmgFlat = 0
    
# Dmg Bonus
    ,dmgBonusElemental = 46.6
    ,dmgBonusOther = 0
    
# Crit
    ,critRate = 12.8
    ,critDmg = 0
    
# Multipliers
    ,quickenType = Inherit
    ,quickenDmgBonus = 0
    ,quickenCount = 0 
    ,amplifyType = Inherit
    ,amplifyDmgBonus = 0
    ,customMultiplier = Inherit
    
# Enemy Stats
    ,levelEnemy = Inherit
    ,resBase = Inherit
    ,resShred = 0
    ,defShred = 0
    ,defIgnore = 0
    
# Conversions
    ,convertToAtk = Inherit
    ,convertToHp = Inherit
    ,convertToDef = Inherit
    ,convertToER = Inherit
    ,convertToEM = Inherit
    
    ,convertToDmgFlat = Inherit
    ,convertToDmgBonus = Inherit
    ,convertToCritRate = Inherit
    ,convertToCritDmg = Inherit
    
# Buff Status
    ,buffStatus = True
)


# Calculation Script
cid = 0
data[cid].label = label
data[cid].calculate(base, custom, globalBuffs)
# Out:
# Atk = 2579.508
# Hp = 0.0
# Def = 0.0
# ER = 100
# EM = 0
# Dmg Bonus = 246.6
# Crit Rate = 100
# Crit Damage = 194.1
# Dmg Non Crit = 5397.871992029999
# Dmg Average = 15875.141528560229
# Dmg Crit = 15875.141528560229

# %% [markdown]
# #### **Data 2**

# %%
label = "Atk Goblet"

custom = complete(

    calculationMode = calculationMode,
    level = Inherit
    
    ,elementalMastery = 0
    ,energyRecharge = 0
    
# Atk
    ,atkBase = Inherit
    ,atkPercent = 46.6
    ,atkFlat = 18
    
# Hp
    ,hpBase = Inherit
    ,hpPercent = 0
    ,hpFlat = 0
    
# Def
    ,defBase = Inherit
    ,defPercent = 0
    ,defFlat = 0
    
# Dmg
    ,motionValue = Inherit
    ,dmgFlat = 0
    
# Dmg Bonus
    ,dmgBonusElemental = 0
    ,dmgBonusOther = 0
    
# Crit
    ,critRate = 14.8
    ,critDmg = 14.0
    
# Multipliers
    ,quickenType = Inherit
    ,quickenDmgBonus = 0
    ,quickenCount = 0 
    ,amplifyType = Inherit
    ,amplifyDmgBonus = 0
    ,customMultiplier = Inherit
    
# Enemy Stats
    ,levelEnemy = Inherit
    ,resBase = Inherit
    ,resShred = 0
    ,defShred = 0
    ,defIgnore = 0
    
# Conversions
    ,convertToAtk = Inherit
    ,convertToHp = Inherit
    ,convertToDef = Inherit
    ,convertToER = Inherit
    ,convertToEM = Inherit
    
    ,convertToDmgFlat = Inherit
    ,convertToDmgBonus = Inherit
    ,convertToCritRate = Inherit
    ,convertToCritDmg = Inherit
    
# Buff Status
    ,buffStatus = True
)


# Calculation Script
cid = 1
data[cid].label = label
data[cid].calculate(base, custom, globalBuffs)
# Out:
# Atk = 3016.116
# Hp = 0.0
# Def = 0.0
# ER = 100
# EM = 0
# Dmg Bonus = 200.0
# Crit Rate = 100
# Crit Damage = 208.1
# Dmg Non Crit = 5462.940104999999
# Dmg Average = 16831.318463505
# Dmg Crit = 16831.318463505

# %% [markdown]
# #### **Data 3**

# %%
label = "Hydro Goblet Kokomi"

custom = complete(

    calculationMode = calculationMode,
    level = Inherit
    
    ,elementalMastery = 0
    ,energyRecharge = 0
    
# Atk
    ,atkBase = Inherit
    ,atkPercent = 5.8 + 20 + 48
    ,atkFlat = 0
    
# Hp
    ,hpBase = Inherit
    ,hpPercent = 0
    ,hpFlat = 0
    
# Def
    ,defBase = Inherit
    ,defPercent = 0
    ,defFlat = 0
    
# Dmg
    ,motionValue = Inherit
    ,dmgFlat = 0
    
# Dmg Bonus
    ,dmgBonusElemental = -40 + 46.6
    ,dmgBonusOther = 0
    
# Crit
    ,critRate = 12.8
    ,critDmg = 0
    
# Multipliers
    ,quickenType = Inherit
    ,quickenDmgBonus = 0
    ,quickenCount = 0 
    ,amplifyType = Inherit
    ,amplifyDmgBonus = 0
    ,customMultiplier = Inherit
    
# Enemy Stats
    ,levelEnemy = Inherit
    ,resBase = Inherit
    ,resShred = 0
    ,defShred = 0
    ,defIgnore = 0
    
# Conversions
    ,convertToAtk = Inherit
    ,convertToHp = Inherit
    ,convertToDef = Inherit
    ,convertToER = Inherit
    ,convertToEM = Inherit
    
    ,convertToDmgFlat = Inherit
    ,convertToDmgBonus = Inherit
    ,convertToCritRate = Inherit
    ,convertToCritDmg = Inherit
    
# Buff Status
    ,buffStatus = True
)


# Calculation Script
cid = 2
data[cid].label = label
data[cid].calculate(base, custom, globalBuffs)
# Out:
# Atk = 3277.188
# Hp = 0.0
# Def = 0.0
# ER = 100
# EM = 0
# Dmg Bonus = 206.6
# Crit Rate = 100
# Crit Damage = 194.1
# Dmg Non Crit = 6066.394513829999
# Dmg Average = 17841.26626517403
# Dmg Crit = 17841.26626517403

# %% [markdown]
# #### **Comparison**

# %% [markdown]
# **% Difference**

# %%
diff(data)

# %% [markdown]
# **Plot comparison**

# %%
plot(data, origin = 1)
print(globalBuffs)
# Out:
# Buffs:
#
# Atk%: 0%
# Atk: 0
# Hp%: 0%
# Hp: 0
# Def%: 0%
# Def: 0
# Dmg Bonus: 164.0%
# Dmg Flat: 0
# Crit Rate: 0%
# Crit Dmg: 0%
# Quicken Dmg Bonus: 0%
# Amplify Dmg Bonus: 0%
# Def Shred: 0
# Def Ignore:0
# Res Shred: 20%
